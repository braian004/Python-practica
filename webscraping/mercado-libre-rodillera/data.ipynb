# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd
from lxml import etree

# %%
r = requests.get("https://listado.mercadolibre.com.ar/rodilleras-deportivas")

# %%
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.content,'html.parser')

# %%
rodilleras_titles = soup.find_all("h2",class_="ui-search-item__title")
rodilleras_titles = [i.text for i in rodilleras_titles]

# %%
dom = etree.HTML(str(soup))
rodilleras_urls = dom.xpath("//a[@class='ui-search-item__group__element ui-search-link']/@href")
#<a href="https://www.mercadolibre.com.ar/rodilleras-deportivas-voley-alto-impacto-ez-life-talle-m-adulto/p/MLA26951489#searchVariation=MLA26951489&amp;position=1&amp;search_layout=stack&amp;type=product&amp;tracking_id=ca51abac-6a73-4368-93cb-bb0f764031f7" class="ui-search-item__group__element ui-search-link" title="Rodilleras Deportivas Voley Alto Impacto  Ez Life Talle M Adulto"><h2 aria-level="3" class="ui-search-item__title">Rodilleras Deportivas Voley Alto Impacto  Ez Life Talle M Adulto</h2></a>

# %%
rodilleras_precios = soup.find_all("span",class_="andes-money-amount ui-search-price__part ui-search-price__part--medium andes-money-amount--cents-superscript")

rodilleras_precios = [i.text for i in rodilleras_precios] 
print(len(rodilleras_precios))
# <span class="andes-money-amount ui-search-price__part ui-search-price__part--medium andes-money-amount--cents-superscript" style="font-size:24px" role="img" aria-label="11416 pesos" aria-roledescription="Precio"><span class="andes-money-amount__currency-symbol" aria-hidden="true">$</span><span class="andes-money-amount__fraction" aria-hidden="true">11.416</span></span>
# Out:
# 54

# %%
def rod (rodilleras_titles,rodilleras_precios,rodilleras_urls):
    lista_rodilleras = []
    lista_precios = []
    lista_urls = []
    for i in rodilleras_titles,rodilleras_precios,rodilleras_urls:
        title_text = i.get_text()
        lista_rodilleras.append(title_text)
        lista_precios.append(title_text)
        lista_urls.append(title_text)
    return lista_rodilleras,lista_precios,lista_urls

# %%
print(len(rodilleras_titles))
print(len(rodilleras_urls))
print(len(rodilleras_precios))
# Out:
# 54
# 54
# 54

# %%
# df = pd.DataFrame({'titulos':rodilleras_titles,'precios':rodilleras_precios,'urls':rodilleras_urls})
# df.to_csv('rodrillera-page.xlsx', index=False)
#xlsx

# %% [markdown]
# ### URL ALL

# %%
siguiente = soup.find_all("a",class_="andes-pagination__link ui-search-link")
siguiente = [i.get('href') for i in siguiente]
siguiente
# Out:
# ['https://listado.mercadolibre.com.ar/rodilleras-deportivas_Desde_51_NoIndex_True']

# %%
dom = etree.HTML(str(soup)) #FUNCIONA SOLO WITH XPATH
siguiente = dom.xpath("//li[@class='andes-pagination__button andes-pagination__button--next']/a")
siguiente = [i.get('href') for i in siguiente]
siguiente
#<a href="https://listado.mercadolibre.com.ar/rodilleras-deportivas_Desde_51_NoIndex_True" class="andes-pagination__link ui-search-link" title="Siguiente" role="button" rel="nofollow"><span class="andes-pagination__arrow-title">Siguiente</span><span class="andes-pagination__arrow"></span></a>
# dom = etree.HTML(str(soup))
# siguiente =dom.xpath('//a[@class="andes-pagination__link ui-search-link"]/@href')
# siguiente
# Out:
# ['https://listado.mercadolibre.com.ar/rodilleras-deportivas_Desde_51_NoIndex_True']

# %%
ini = soup.find("li",class_="andes-pagination__button andes-pagination__button--current")
ini= int(ini.text)
ini
# Out:
# 1

# %%
# <li class="andes-pagination__page-count">de <!-- -->28</li>
can = soup.find("li",class_="andes-pagination__page-count")
can = can.text
can = int(can.replace("de ",""))
can
# Out:
# 26

# %%
lista_titulos = []
lista_urls = []
lista_precios = []

# %%
siguiente = "https://listado.mercadolibre.com.ar/rodilleras-deportivas_Desde_1_NoIndex_True"
while True:
    r = requests.get(siguiente)
    if r.status_code == 200:
        soup = BeautifulSoup(r.content, 'html.parser')

        rodilleras_titles = soup.find_all("h2",class_="ui-search-item__title")
        rodilleras_titles = [i.text for i in rodilleras_titles]
        lista_titulos.extend(rodilleras_titles)
        
        dom = etree.HTML(str(soup))
        rodilleras_urls = dom.xpath("//a[@class='ui-search-item__group__element ui-search-link']/@href")    
        lista_urls.extend(rodilleras_urls)
        
        rodilleras_precios = soup.find_all("span",class_="andes-money-amount ui-search-price__part ui-search-price__part--medium andes-money-amount--cents-superscript")
        rodilleras_precios = [i.text for i in rodilleras_precios] 
        lista_precios.extend(rodilleras_precios)

        ini = soup.find("li",class_="andes-pagination__button andes-pagination__button--current")
        ini= int(ini.text)

        can = soup.find("li",class_="andes-pagination__page-count")

        can = can.text
        can = int(can.replace("de ",""))

    else:
        break
    print(ini,can)    
    if ini == can:
        break

    dom = etree.HTML(str(soup))
    siguiente = dom.xpath("//li[@class='andes-pagination__button andes-pagination__button--next']/a")[0].get('href')
# Out:
# 1 26
# 2 26
# 3 26
# 4 26
# 5 26
# 6 26
# 7 26
# 8 26
# 9 26
# 10 26
# 11 26
# 12 26
# 13 26
# 14 26
# 15 26
# 16 26
# 17 26
# 18 26
# 19 26
# 20 26
# 21 26
# 22 26
# 23 26
# 24 26
# 25 26
# 26 26

# %%
print(len(lista_titulos))
print(len(lista_urls))
print(len(lista_precios))
# Out:
# 1431
# 1431
# 1431

# %%
df = pd.DataFrame({'Titulos':lista_titulos,"Precio":lista_precios,"Urls":lista_urls})
df
# Out:
#                                                 Titulos   Precio  \
# 0     Rodilleras Deportivas Voley Alto Impacto  Ez L...  $13.650
# 1     Rodilleras Deportivas Voley Alto Impacto Ez Li...  $13.650
# 2     Rodilleras Deportivas Voley Alto Impacto Ez Li...  $13.650
# 3     Rodilleras Proyec Alto Impacto Voley Acolchada...  $19.140
# 4     Rodilleras + Coderas Scoyco Yds Motocross Atv ...  $53.079
# ...                                                 ...      ...
# 1426         Medias Altas Calzas Motocross Sox Titanium  $16.073
# 1427  Traumatologia, Deportistas: Rodillera Con Orif...   $9.000
# 1428  Rodillera Elástica Ortopédica Deportiva Compre...  $17.334
# 1429  Rodillera Elástica Ortopédica Deportiva Compre...  $13.834
# 1430  Codera Rodillera Azul Aire Libre Deportes Fayd...  $10.032
#
#                                                    Urls
# 0     https://www.mercadolibre.com.ar/rodilleras-dep...
# 1     https://www.mercadolibre.com.ar/rodilleras-dep...
# ...

# %%
df.to_csv('data-ml-Rodilleras.xlsx',index=False)
df
# Out:
#                                                 Titulos   Precio  \
# 0     Rodilleras Deportivas Voley Alto Impacto  Ez L...  $13.650
# 1     Rodilleras Deportivas Voley Alto Impacto Ez Li...  $13.650
# 2     Rodilleras Deportivas Voley Alto Impacto Ez Li...  $13.650
# 3     Rodilleras Proyec Alto Impacto Voley Acolchada...  $19.140
# 4     Rodilleras + Coderas Scoyco Yds Motocross Atv ...  $53.079
# ...                                                 ...      ...
# 1426         Medias Altas Calzas Motocross Sox Titanium  $16.073
# 1427  Traumatologia, Deportistas: Rodillera Con Orif...   $9.000
# 1428  Rodillera Elástica Ortopédica Deportiva Compre...  $17.334
# 1429  Rodillera Elástica Ortopédica Deportiva Compre...  $13.834
# 1430  Codera Rodillera Azul Aire Libre Deportes Fayd...  $10.032
#
#                                                    Urls
# 0     https://www.mercadolibre.com.ar/rodilleras-dep...
# 1     https://www.mercadolibre.com.ar/rodilleras-dep...
# ...
