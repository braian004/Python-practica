# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from lxml import etree

# %%
url = "https://listado.mercadolibre.com.ar/rodilleras-deportivas#D[A:rodilleras%20deportivas]"
r = requests.get(url)
soup = BeautifulSoup(r.content, "html.parser")

# Find all the <h2> elements with the specified class
rodilleras_titles = soup.find_all('h2', class_="ui-search-item__title")

# %%
def extract_titles(html_titles):
    cleaned_titles = []
    for title in html_titles:
        # Extract the text within the <h2> tags
        title_text = title.get_text()
        cleaned_titles.append(title_text)
    return cleaned_titles

# Call the function to extract the titles
cleaned_product_titles = extract_titles(rodilleras_titles)

# Print the cleaned product titles
for title in cleaned_product_titles:
    print(title)
# Out:
# Rodillera Deportiva Compresion Ligamentos Meniscos Profit
# Rodillera Pemium Ortopedica Deportiva Meniscos Cruzado
# Rodilleras Nassau Profesionales Voley Handball Baile Patin Color Azul Talle Xs
# Rodillera Meniscos Ligamento Cruzado Ortopedica Deportiva
# Rodillera Deportiva Elástica Ortopédica Rodilla Compresión
# Rodillera Pemium Meñiscos Ajuste Cruzado Unisex Deportiva
# Rodillera Elástica Ortopédica Deportiva Compresión Meniscos
# Rodillera Deportiva Con Banda Dinámica De Ajuste Crossfit
# Combo Rodillera Deportiva Elástica Meniscos Air Sport X2unid
# Set Protecciones Rodillera Codera Muñequera Skate Patin
# Rodillera Deportiva Voley Patín Handball Hockey One Flex Bander Green
# Rodillera Ortopédica Elástica Deportiva Excelente Premium
# Protección Infantil Rodillera Codera Y Manopla
# Rodillera Elastica Deportiva Anti Esguince Soporte Raia
# Rodillera Doble Ajuste Pemium Ligamentos Meñiscos Unisex
# Rodilleras Acolchadas Alto Impacto Body Therm Boedo Deportes
# Rodilleras Ez Life Voley Reforazada Acolchada Patin Danza
# Rodillera Pemium Ortopedica Deportiva Meniscos Cruzado
# Combo Rodillera Deportiva Elástica Air Sport Meniscos X2
# Kit Entrenamiento Rodillera Deportes Y Toallas Humedas Wipes
# Rodillera Gimnasia Deportes Fitness Alta Competencia Lycra
# Rodillera Con Banda Dinámica Ajuste Crossfit Deportiva Ptm
# Rodillera Ortopedica Premium Deportiva Meniscos Cruzado
# Rodillera Ez Life  Vóley / Hockey /  Handball Acolchada
# Rodillera Pemium Meñiscos Unisex Deportiva Refuerzo Lateral
# Cincha Rotuliana Rodillera Menisco Menisquera Rotula Neop.
# Rodilleras Voley Acolchadas Alto Impacto Deportivas Handball
# Rodillera Voley Patin Danza Mma Acolchada Deportiva
# Rodillera Deportiva Anti Golpes Reforzada Importada Gymtonic
# Rodilleras Voley Acolchadas Alto Impacto Deportivas Handball Talle L
# Rodillera Abierta Ajustable Con Abrojo Rotula Deportes
# Rodillera Deportiva Elástica Air Sport Rodilla Ligamentos Meniscos Compresión Esguince Ortopédica Soporte
# Kit Protección Deportes Gadnic Prt1 Rodilleras Y Coderas
# 2 Rodilleras Deportes Fitness Crossfit Alta Competencia La +
# Rodilleras Voley Acolchadas Alto Impacto Deportivas Handball Talle S
# Rodillera Deportiva One Flex Neoprene Voley Handball Hockey
# Rodillera Voley Nassau Cover Unisex Black
# Drb Rodillera - Vóley Jump
# Rodillera Deportiva Elastica Anti Esguince Compresion Raia
# Drb Rodillera Kids - Jump Jr
# Rodilleras Voley Nassau Profesionales
# Rodillera Deportiva Air Sport Elástica Profit Ptm Oficial
# Rodillera Crossfit Neoprene Deportiva Rotula Rotuliana Dema
# Rodillera Elastica Sosten Rotula Manga Compresion  Deportes
# Rodillera Deportiva Elastica Anti Esguince Compresion Unisex
# Rodilleras Voley Alto Impacto Acolchada  Deportiva Handball
# Rodillera Rotula Soporte Con Abrojo Deporte Neoprene
# Par De Rodilleras Acolchadas Ez Life Danza Voley Patin Thai
# Rodillera Elastic Pro Bander Green Deportes Lesiones Talle L
# Nassau Rodillera - Voley Cover Rjo
# Rodillera Pemium Meñiscos Unisex Deportiva Refuerzo Lateral
# Protecciones Patin Roller Rodilleras + Coderas + Muñequeras
# Rodilleras Proyec Alto Impacto Voley Acolchada Patin Arquero Color Negro Talle L
# Rodillera Voley Ez Life Entrenamiento Deportivas

# %% [markdown]
# ### URL ALL

# %%
dom = etree.HTML(str(soup))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Tito\Desktop\Python-practica\webscraping\data.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tito/Desktop/Python-practica/webscraping/data.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> dom = etree.HTML(str(soup))
#
# NameError: name 'etree' is not defined

# %%
siguiente = dom.spath('//div[@class="ui-search-pagination"]/nav/ul/li[contains(@class,"--next")]/a')
#fatal dom.spath
